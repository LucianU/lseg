# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
from pathlib import Path

# Add the project root to sys.path so you can import lseg.*
project_root = Path().resolve().parent
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

# %%
from lseg.preprocessing import load_price_data
from lseg.evals import evaluate_gbm, evaluate_arima, evaluate_ensemble

# %%
from os import path
data_dir = path.join(project_root, 'data/Price_History_2025.xlsx')

df = load_price_data(data_dir)
evaluate_ensemble(df, plot=True)
# Out:
# Ensemble Metrics: {'MAE': np.float64(1.314143764985016), 'RMSE': np.float64(1.456724695305902), 'Directional Accuracy': np.float64(0.2)}

# %%
evaluate_gbm(df, plot=True)
# Out:
# GBM Evaluation Metrics: {'MAE': np.float64(1.2617865305750116), 'RMSE': np.float64(1.3978407191729456), 'Directional Accuracy': np.float64(0.2)}

# %%
evaluate_arima(df, plot=True)
# Out:
# ARIMA Evaluation Metrics: {'MAE': np.float64(1.3665009993950037), 'RMSE': np.float64(1.5328481765444963), 'Directional Accuracy': np.float64(0.4)}
